# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

f=open('c:/Users/82107/Desktop/a.csv')
d=csv.reader(f)
next(d)
temp=[]
temp2=[]

for k in d :
    if '역삼1동' in k[0] :
        for i in range(24, 34):
            temp.append(int(k[i].replace(',','')))
            
plt.plot(temp, label='y1', linewidth='5')
plt.grid()
plt.rc('font',family='Malgun Gothic')
plt.xticks(np.arange(0,9,2),('20살', '22살', '24살', '26살', '28살'))
plt.legend(loc = 'upper left')
plt.show()
