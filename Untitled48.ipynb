# %%
import matplotlib.pyplot as plt
import numpy as np

year = [1999, 2000, 2001, 2002, 2003]
birth = [1006645, 862835, 649738, 634501, 470171]

#a = np.arange(len(year))    # 0,5,1 찍어도 같은결과 출력.
#plt.xticks(a,year)          # x축의 값의 간격이 1이 아닐때 사용 # 사실 그냥 x값에 ' '붙이는게 편할듯.
plt.ylim(300000,1000000)    #y값의 범위
plt.xlabel('year')
plt.ylabel('population')
plt.title('Analysis')

plt.bar(year, birth, width=0.7, color = 'violet',alpha = 0.6) #alpha == 음영 .png는 alpha지원,  but .jpg는 미지원
# Out:
# <BarContainer object of 5 artists>
